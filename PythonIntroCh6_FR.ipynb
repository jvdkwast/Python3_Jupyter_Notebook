# %% [markdown]
# < [Tuples, Listes, et Dictionnaires](PythonIntroCh5_FR.ipynb) | [Contenu](PythonIntro_FR.ipynb) | [Classes](PythonIntroCh7_FR.ipynb) >

# %% [markdown]
# # 6. Boucle For
# ## 6.1 Introduction
# Dans la première leçon sur les boucles, j'ai dit que je ne vous apprendrais la boucle for que lorsque nous aurions atteint les listes. Eh bien, nous y sommes!
# ## 6.2 La boucle `for`
# En gros, la boucle `for` fait quelque chose pour chaque valeur d'une liste. La façon dont elle est présentée est un peu confuse, mais en fait elle est très basique. Voici un exemple de code:

# %%
# Exemple de boucle 'for'
# D'abord, créez une liste à parcourir en boucle:
NouvelleListe = [45, 'mange moi', 90210, "Le jour est venu, dit le morse, \
de parler de beaucoup de choses", -67]

# créer la boucle:
# parcourir newList, et mettre séquentiellement chaque bit d'information
# dans la variable valeur, et exécute la boucle
for valeur in NouvelleListe:
    print(valeur)

# %% [markdown]
# Comme vous le voyez, lorsque la boucle s'exécute, elle parcourt toutes les valeurs de la liste mentionnée après `in`. Elle les place ensuite dans `valeur`, et exécute la boucle, pour chaque différent élément de valeur. Voyons encore une fois, dans un appel classique de cheerleading que nous connaissons tous:

# %%
# Program de cheerleading
mots = input("Qui choisissez-vous? ")

for lettre in mots:
    appel = "Dites " + lettre + "!"
    print(appel)
    print(lettre + "!")

print("Comment ça se dit?")
print(mots + "!")

# %% [markdown]
# Voici ce que vous venez retenir:
# * Comme vous le voyez, les chaînes de caractères (rappelez-vous - les chaînes de caractères sont des lignes de texte) sont juste des listes avec beaucoup de caractères.
# * Le programme a parcouru chacune des lettres (ou valeurs) de mots, et il les a affiché à l'écran.<br>

# %% [markdown]
# Et c'est tout ce qu'il y a à faire avec la boucle.

# %% [markdown]
# ## 6.3 Création d'une fonction menu
# Passons maintenant à la partie pratique de la leçon. Commençons à écrire des programmes. Jusqu'à présent, nous avons appris les variables, les listes, les boucles et les fonctions. C'est à peu près tout ce dont nous avons besoin pour une bonne partie de la programmation. Nous allons donc nous fixer une tâche.

# %% [markdown]
# ```Python
# # LA FONCTION MENU
# # Le programme demande une chaîne de caractères contenant toutes les options du menu,
# # et une chaîne de texte posant une question.
# # Assurez-vous que chaque entrée du menu est unique.
#
# def menu(list, question):
#     for entry in list:
#         print(1 + list.index(entry),end=""))
#         print (") " + entry)
#
#     return eval(input(question)) - 1
#
# # def menu(list, question): dit à la fonction de
# # demander deux éléments d'information:
# # une liste de toutes les entrées du menu,
# # et la question qu'elle posera lorsque toutes les options auront été affichées
#
# # for entry in list: dit à peu près cesi;
# #'"pour chaque entrée de la liste, faites ce qui suit:'
#
# # print list.index(entry) + 1 utilise la fonction .index() pour trouver
# # où se trouve l'entrée dans la liste. La fonction print l'affiche alors
# # elle ajoute 1 pour rendre les chiffres plus intelligibles.
#
# # print ") " + entry affiche une parenthèse, puis le nom de l'entrée
#
# # après que la boucle for soit terminée, eval(input(question) - 1) pose la question,
# # et renvoie la valeur au programme principal (moins 1, pour la ramener à un nombre
# # le nombre que l'ordinateur comprendra).
# ```

# %% [markdown]
# Ce n'était pas très difficile, n'est-ce pas ? Le programme proprement dit n'occupe que cinq lignes - c'est dire à quel point nous avons appris jusqu'à présent ! Tous mes commentaires occupent seize lignes, soit plus de trois fois la longueur du programme. C'est une bonne idée de commenter abondamment vos programmes. N'oubliez pas que si vous publiez votre code en open-source, de nombreuses personnes vont vérifier le code que vous avez écrit. Nous allons voir la fonction que nous venons d'écrire dans notre premier exemple de programme.

# %% [markdown]
# ## 6.4 Notre premier 'Jeu'
# Quel sera notre premier exemple de programme? Que diriez-vous d'un jeu d'aventure textuel (très) simple ? Ça a l'air amusant ! Il ne concernera qu'une seule pièce d'une maison, et sera extrêmement simple. Il y aura cinq objets et une porte. Dans l'un des cinq objets se trouve la clé de la porte. Vous devez trouver la clé, puis ouvrir la porte. Je vais d'abord donner une version en français, puis en Python:<br>
# ```
# #Version francçaise de notre "jeu"
#
# Indiquer à l'ordinateur la fonction de notre menu
#
# Afficher un message de bienvenue, montrant une description de la pièce.
# Nous allons donner au joueur six choses à regarder : une plante en pot, un tableau,\
# un vase, un abat-jour, une chaussure et la porte
#
# Indiquer à l'ordinateur que la porte est verrouillée
# Indiquer à l'ordinateur où se trouve la clé
#
# Présentez un menu qui vous indique les objets que vous pouvez "manipuler":
#     Il vous donnera les six options
#     Il posera la question "que voulez-vous regarder?"
#
# si l'utilisateur veut regarder:
#     la plante en pot:
#         Si la clé y est, donner la clé au joueur
#         sinon, lui dire qu'elle n'est pas là
#     tableau:
#         même chose que ci-dessus
#     etc.
#     porte:
#         Si le joueur a la clé, le laisser ouvrir la porte
#         Sinon, lui dire de chercher d'avantage
#
# Donnez au joueur un message de félicitations, pour avoir terminé le jeu.
# ```
# <br>
# A partir ceci, nous pouvons écrire un vrai programme. Vous êtes prêts ? C'est parti:

# %%
# JEU D'AVENTURE TEXTUEL

#la fonction menu:
def menu(list, question):
    for entry in list:
        print(1 + list.index(entry),end="")
        print (") " + entry)

    return eval(input(question)) - 1

#Donnez à l'ordinateur quelques informations de base sur la pièce:
objets = ["plante en pot","tableau","vase","abat-jour","chaussure","porte"]

#La clé se trouve dans le vase (ou l'entrée numéro 2 dans la liste ci-dessus):
localisationclé = 2

#Vous n'avez pas trouvé la clé:
clétrouvée = 0

boucle = 1

#Donnez le texte d'introduction:
print("La nuit dernière, vous vous êtes endormi dans le confort de votre propre maison.")

print("Maintenant, vous vous retrouvez enfermés dans une pièce. Vous ne savez pas comment")
print("vous êtes arrivé là, ou quelle heure il est. Dans la pièce, vous pouvez voir")
print(len(objets), "objets:")
for x in objets:
    print(x)
print("")
print("La porte est fermée, y aurait-il une clé quelque part?")
#Faites fonctionner votre menu et le programme jusqu'à ce que vous trouviez la clé:
while boucle == 1:
    choix = menu(objets,"Que voulez-vous inspecter? ")
    if choix == 0:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans la plante en pot.")

            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans la plante en pot.")
            print("")
    elif choix == 1:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé derrière le tableau.")
            print("")

            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé derrière le tableau.")
            print("")
    elif choix == 2:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans le vase.")
            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans le vase.")

            print("")
    elif choix == 3:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans l'abat-jour.")
            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans l'abat-jour.")
            print("")

    elif choix == 4:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans la chaussure.")
            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans la chaussure.")
            print("")
    elif choix == 5:
        if clétrouvée == 1:
            boucle = 0
            print("Vous mettez la clé, vous la tournez, et vous entendez un clic")

            print("")
        else:
            print("La porte est fermée, vous devez trouver une clé.")
            print("")

# Rappelez-vous qu'une barre oblique inverse poursuit
# le code sur la ligne suivante
print("La lumière pénètre dans la pièce lorsque \
vous ouvrez la porte de votre liberté.")

# %% [markdown]
# Eh bien, un jeu très simple, mais amusant. Ne vous laissez pas décourager par la quantité de code, 53 des lignes ne sont que des instructions "si", ce qui est la chose la plus facile à lire (une fois que vous avez compris l'indentation). Bientôt vous ferez votre propre jeu, et vous pourrez le rendre aussi simple (ou aussi complexe) que vous le souhaitez. Je vais en poster quelques uns, plus tard.

# %% [markdown]
# ## 6.5 Rendre le jeu meilleur
# La première question que vous devez vous poser est "ce programme fonctionne-t-il ?". La réponse est oui. Ensuite, vous devriez demander "est-ce que ce programme fonctionne bien ?" - pas tout à fait. La fonction `menu()` est géniale - elle réduit beaucoup la saisie. La boucle `while` que nous avons, cependant, est un peu désordonnée - quatre niveaux d'indentations, pour un programme simple. Nous pouvons faire mieux!
#
# Maintenant, cela deviendra beaucoup BEAUCOUP plus simple quand nous introduirons les classes. Mais cela devra attendre. En attendant, créons une fonction qui réduira notre désordre. Nous lui transfèrera deux choses - le choix de menu que nous avons fait, et l'emplacement de la clé. Elle retournera une chose - si oui ou non la clé a été trouvée. Voyons cela:
#
# ```Python
# def inspect(choix,localisationclé):
#     if choix == localisationclé:
#         print("")
#         print("Vous avez trouvé une clé!")
#         print("")
#         return 1
#     else:
#         print("")
#         print("Rien d'intéressant ici.")
#         print("")
#         return 0
# ```
#
#
# Maintenant le programme principal peut être un peu plus simple.
#
# Dans le champ ci-dessous:
#
# 1. Inserez la fonction `inspect`
# 2. Remplacez la boucle `while` par:
#
# ```Python
# while boocle == 1:
#     clétrouvée = inspect(menu(objets,"Que voulez-vous inspecter? "),localisationclé)
#     if clétrouvée == 1:
#         print("Vous mettez la clé dans la serrure de la porte, et vous la tournez. Elle s'ouvre!")
#         loop = 0
# ```

# %%
# JEU D'AVENTURE TEXTUEL

#la fonction menu:
def menu(list, question):
    for entry in list:
        print(1 + list.index(entry),end="")
        print (") " + entry)

    return eval(input(question)) - 1

#Donnez à l'ordinateur quelques informations de base sur la pièce:
objets = ["plante en pot","tableau","vase","abat-jour","chaussure","porte"]

#La clé se trouve dans le vase (ou l'entrée numéro 2 dans la liste ci-dessus):
localisationclé = 2

#Vous n'avez pas trouvé la clé:
clétrouvée = 0

boucle = 1

#Donnez le texte d'introduction:
print("La nuit dernière, vous vous êtes endormi dans le confort de votre propre maison.")

print("Maintenant, vous vous retrouvez enfermés dans une pièce. Vous ne savez pas comment")
print("vous êtes arrivé là, ou quelle heure il est. Dans la pièce, vous pouvez voir")
print(len(objets), "objets:")
for x in objets:
    print(x)
print("")
print("La porte est fermée, y aurait-il une clé quelque part?")
#Faites fonctionner votre menu et le programme jusqu'à ce que vous trouviez la clé:
while boucle == 1:
    choix = menu(objets,"Que voulez-vous inspecter? ")
    if choix == 0:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans la plante en pot.")

            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans la plante en pot.")
            print("")
    elif choix == 1:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé derrière le tableau.")
            print("")

            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé derrière le tableau.")
            print("")
    elif choix == 2:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans le vase.")
            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans le vase.")

            print("")
    elif choix == 3:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans l'abat-jour.")
            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans l'abat-jour.")
            print("")

    elif choix == 4:
        if choix == localisationclé:
            print("Vous avez trouvé une petite clé dans la chaussure.")
            print("")
            clétrouvée = 1
        else:
            print("Vous n'avez rien trouvé dans la chaussure.")
            print("")
    elif choix == 5:
        if clétrouvée == 1:
            boucle = 0
            print("Vous mettez la clé, vous la tournez, et vous entendez un clic")

            print("")
        else:
            print("La porte est fermée, vous devez trouver une clé.")
            print("")

# Rappelez-vous qu'une barre oblique inverse poursuit
# le code sur la ligne suivante
print("La lumière pénètre dans la pièce lorsque \
vous ouvrez la porte de votre liberté.")

# %% [markdown]
# Maintenant, le programme devient beaucoup plus court - d'un encombrant 83 lignes, à un très élégant 50 lignes ! Bien sûr, vous perdez un peu de polyvalence - tous les objets de la pièce font la même chose. Vous ouvrez automatiquement la porte lorsque vous trouvez la clé. Le jeu devient un peu moins intéressant. Il devient également un peu plus difficile à modifier.

# %% [markdown]
# ## 6.6 Conclusion
# J'ai dit que vous alliez écrire des programmes maintenant. Voici votre chance ! Votre tâche, si vous choisissez de l'accepter, est de poster un meilleur jeu d'aventure textuel. Vous pouvez utiliser n'importe lequel des codes que je vous ai donnés ici. N'oubliez pas de consulter les leçons précédentes que nous avons faites - ce sont des outils inestimables. Faites une recherche pour trouver des jeux d'aventure textuels simples - si vous trouvez des jeux d'aventure textuels agréables et amusants, jetez-y un coup d'œil.

# %% [markdown]
# < [Tuples, Listes, et Dictionnaires](PythonIntroCh5_FR.ipynb) | [Contenu](PythonIntro_FR.ipynb) | [Classes](PythonIntroCh7_FR.ipynb) >
